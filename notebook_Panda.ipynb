# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import matplotlib
from jedi.api.refactoring import inline

print("Hello World!")
print('hello')

# %%
print("Hello")

# %%
import pandas as pd
df= pd.read_csv("/Users/gyanapradhan/Desktop/Employee_Salary_Dataset.csv")
df.count()
# Out:
# ID                  35
# Experience_Years    35
# Age                 35
# Gender              35
# Salary              35
# dtype: int64

# %%
df.shape
df.describe
# Out:
# <bound method NDFrame.describe of     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# ...

# %%
df.describe

# %%
df.values
# Out:
# array([[1, 5, 28, 'Female', 250000],
#        [2, 1, 21, 'Male', 50000],
#        [3, 3, 23, 'Female', 170000],
#        [4, 2, 22, 'Male', 25000],
#        [5, 1, 17, 'Male', 10000],
#        [6, 25, 62, 'Male', 5001000],
#        [7, 19, 54, 'Female', 800000],
#        [8, 2, 21, 'Female', 9000],
#        [9, 10, 36, 'Female', 61500],
#        [10, 15, 54, 'Female', 650000],
#        [11, 4, 26, 'Female', 250000],
#        [12, 6, 29, 'Male', 1400000],
#        [13, 14, 39, 'Male', 6000050],
#        [14, 11, 40, 'Male', 220100],
#        [15, 2, 23, 'Male', 7500],
#        [16, 4, 27, 'Female', 87000],
#        [17, 10, 34, 'Female', 930000],
#        [18, 15, 54, 'Female', 7900000],
#        [19, 2, 21, 'Male', 15000],
#        [20, 10, 36, 'Male', 330000],
#        [21, 15, 54, 'Male', 6570000],
#        [22, 4, 26, 'Male', 25000],
#        [23, 5, 29, 'Male', 6845000],
#        [24, 1, 21, 'Female', 6000],
#        [25, 4, 23, 'Female', 8900],
# ...

# %%
#df['Salary']
df.Salary
# Out:
# 0       250000
# 1        50000
# 2       170000
# 3        25000
# 4        10000
# 5      5001000
# 6       800000
# 7         9000
# 8        61500
# 9       650000
# 10      250000
# 11     1400000
# 12     6000050
# 13      220100
# 14        7500
# 15       87000
# 16      930000
# 17     7900000
# 18       15000
# 19      330000
# 20     6570000
# 21       25000
# 22     6845000
# 23        6000
# 24        8900
# 25       20000
# 26        3000
# 27    10000000
# 28     5000000
# 29        6100
# 30       80000
# 31      900000
# 32     1540000
# 33     9300000
# 34     7600000
# Name: Salary, dtype: int64

# %%
x=df.drop(columns=['ID','Gender','Salary'])

y= df['Salary']
y
# Out:
# 0       250000
# 1        50000
# 2       170000
# 3        25000
# 4        10000
# 5      5001000
# 6       800000
# 7         9000
# 8        61500
# 9       650000
# 10      250000
# 11     1400000
# 12     6000050
# 13      220100
# 14        7500
# 15       87000
# 16      930000
# 17     7900000
# 18       15000
# 19      330000
# 20     6570000
# 21       25000
# 22     6845000
# 23        6000
# 24        8900
# 25       20000
# 26        3000
# 27    10000000
# 28     5000000
# 29        6100
# 30       80000
# 31      900000
# 32     1540000
# 33     9300000
# 34     7600000
# Name: Salary, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier 
model= DecisionTreeClassifier ()
model.fit(x,y)
# Out:
# /Users/gyanapradhan/PyCharmMiscProject/.venv/lib/python3.13/site-packages/sklearn/utils/multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# DecisionTreeClassifier()

# %%
prediction = model.predict([[10,39],[1,18]])
prediction
# Out:
# /Users/gyanapradhan/PyCharmMiscProject/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([220100,   3000])

# %%
predict =model.predict([[3,23],[5,26],[20,50],[25,53]])
predict
# Out:
# /Users/gyanapradhan/PyCharmMiscProject/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([ 170000,  250000, 7600000, 5001000])

# %%
df.columns
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
import pandas as pd
df2=pd.read_csv("/Users/gyanapradhan/Desktop/Bank.csv")

# %%
df2.values
# Out:
# array([['30;"unemployed";"married";"primary";"no";1787;"no";"no";"cellular";19;"oct";79;1;-1;0;"unknown";"no"'],
#        ['33;"services";"married";"secondary";"no";4789;"yes";"yes";"cellular";11;"may";220;1;339;4;"failure";"no"'],
#        ['35;"management";"single";"tertiary";"no";1350;"yes";"no";"cellular";16;"apr";185;1;330;1;"failure";"no"'],
#        ...,
#        ['57;"technician";"married";"secondary";"no";295;"no";"no";"cellular";19;"aug";151;11;-1;0;"unknown";"no"'],
#        ['28;"blue-collar";"married";"secondary";"no";1137;"no";"no";"cellular";6;"feb";129;4;211;3;"other";"no"'],
#        ['44;"entrepreneur";"single";"tertiary";"no";1136;"yes";"yes";"cellular";3;"apr";345;2;249;7;"other";"no"']],
#       shape=(4521, 1), dtype=object)

# %%
df.head(5)
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
df.isnull()
# Out:
#        ID  Experience_Years    Age  Gender  Salary
# 0   False             False  False   False   False
# 1   False             False  False   False   False
# 2   False             False  False   False   False
# 3   False             False  False   False   False
# 4   False             False  False   False   False
# 5   False             False  False   False   False
# 6   False             False  False   False   False
# 7   False             False  False   False   False
# 8   False             False  False   False   False
# 9   False             False  False   False   False
# 10  False             False  False   False   False
# 11  False             False  False   False   False
# 12  False             False  False   False   False
# 13  False             False  False   False   False
# 14  False             False  False   False   False
# 15  False             False  False   False   False
# 16  False             False  False   False   False
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#%matplotlib.style.use('ggplot')
# %matplotlib inline
plt.scatter(df['Experience_Years'],df['Salary'],color="green",marker='+')
